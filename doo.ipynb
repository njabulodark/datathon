# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
def make_list(stri):
        lis = []
        stri = stri.split(',')
        for i in range(len(stri)):
            lis.append(stri[i][2:-1])
        return lis

# %%
def get_data(year, limit):
    #get the tweets from the year
    tweets_list2 = []
    for i,tweet in enumerate(sntwitter.TwitterHashtagScraper(f'corruption since:{year}-01-01 until:{year+1}-01-01').get_items()):
        if i>200:
            break

        if "south africa" in tweet.user.location.lower():
            tw = tweet.content
            tweets_list2.append([tweet.hashtags])

    #make a dataframe
    hash_data = pd.DataFrame(tweets_list2, columns=['Hashtags'])

    #make a list of all the hashtags
    hash_list = hash_data['Hashtags'].tolist()
    #combine all the lists into one list
    lis = []
    for i in range(len(hash_data["Hashtags"])):
        for j in range(len(hash_data["Hashtags"][i])):
            lis.append(hash_data["Hashtags"][i][j])

    #count the number of times each hashtag appears
    from collections import Counter
    Counter(lis)

    #get a list top 3 hashtags
    Counter(lis).most_common(3) 


    # Creating list to append tweet data to
    tweets_list1 = []
    tweets_list2 = []
    tweets_list3 = []

    tw = ''

    
    for i,tweet in enumerate(sntwitter.TwitterHashtagScraper(f'#{Counter(lis).most_common(3)[0][0]} since:2017-01-01 until:2018-01-01').get_items()):
        if i>limit:
            break
        tweets_list1.append([tweet.date.strftime("%y:%m:%d %H:%M:%S"), tweet.content, tweet.user.username, tweet.retweetCount, tweet.user.location, tweet.hashtags])

    for i,tweet in enumerate(sntwitter.TwitterHashtagScraper(f'#{Counter(lis).most_common(3)[1][0]} since:2017-01-01 until:2018-01-01').get_items()):
        if i>limit:
            break
        tweets_list2.append([tweet.date.strftime("%y:%m:%d %H:%M:%S"), tweet.content, tweet.user.username, tweet.retweetCount, tweet.user.location, tweet.hashtags])
    
    for i,tweet in enumerate(sntwitter.TwitterHashtagScraper(f'#{Counter(lis).most_common(3)[2][0]} since:2017-01-01 until:2018-01-01').get_items()):
        if i>limit: 
            break
        tweets_list3.append([tweet.date.strftime("%y:%m:%d %H:%M:%S"), tweet.content, tweet.user.username, tweet.retweetCount, tweet.user.location, tweet.hashtags])

    # Creating a dataframe from the tweets list above
    tweets_df = pd.DataFrame(tweets_list1 + tweets_list2 + tweets_list3, columns=['Datetime', 'Text', 'Username', 'Retweets', 'Location', 'Hashtags'])
    tweets_df.to_csv(f'{year}data.csv', index=False)
    return tweets_df

get_data(2017, 10)
# Out:
#              Datetime                                               Text  \
# 0   17:12:31 23:54:51  #HappyNewYear2018 All the way from #CapeTown #...
# 1   17:12:31 23:25:03  Thought Factory (new): Patronage Politics in #...
# 2   17:12:31 23:05:09  Thought Factory: The DA's Ideological Schizoph...
# 3   17:12:31 22:58:49  @sandrafine2b Thank you Sandra @sandrafine2b. ...
# 4   17:12:31 22:57:24  #Dankie Sandra @sandrafine2b. 🇿🇦🇬🇧#RSA #SouthA...
# 8      BrexitLondon         1  On GAB, Parler. I Follow Back.
# 9   ThoughtFactoryQ         0         Cape Town, South Africa
# 10    HarryHayfield         0              Llanrhystud, Wales
# 11   SchoolNGRclass         0                  Lagos, Nigeria
# 12            hudkr         0                          Joburg
# 13  ThoughtFactoryQ         0         Cape Town, South Africa
# 14          fabfol1         1
# 15     mutlanyana_t         0           Jo'burg. Gauteng, RSA
# 16        naidooinc         0          Pretoria, South Africa
# 17  GreggRobertson5         0                  United Kingdom
# 18   SchoolNGRclass         0                  Lagos, Nigeria
# 19     meginafricas         0       Johannesburg South Africa
# 20     meginafricas         0       Johannesburg South Africa
# 21  citrusramaphosa         0
# 22    AlbertFiorino         1                 Toronto, Canada
# 23     lifemechanik         0
# 24         Jory_Nal         0                    Upper Canada
# 25   KeltonPrisbrey         0               St. George, Utah
# 26      BillHarvey6         4                Hobart, Tasmania
# 27        Robdepamd         1                   United States
# 28         Adunaiii         0
# 29  StephenWunderl4         0                     Seattle, WA
# 30   KeltonPrisbrey         0               St. George, Utah
# 31   KeltonPrisbrey         0               St. George, Utah
# 32       wavetossed         0                   Vancouver, BC
#
#                                              Hashtags
# 0   [HappyNewYear2018, CapeTown, RSA, Fireworks201...
# 1                    [RSA, leadership, politics, ANC]
# 2         [DA, leadership, politics, RSA, HelenZille]
# 3        [RSA, SouthAfrica, SuidAfrika, Suid, Afrika]
# 4                  [Dankie, RSA, SouthAfrica, Africa]
# 5            [RSA, Zuma, corruption, ANC, leadership]
# 6                               [sustainability, RSA]
# 7                                  [RSA, SouthAfrica]
# 8   [London, UK, Africa, RSA, SouthAfrica, HappyNe...
# 9                    [RSA, leadership, politics, ANC]
# 10                                              [RSA]
# 11                                             [Zuma]
# 12                              [zuma, FreeEducation]
# 13           [RSA, Zuma, corruption, ANC, leadership]
# 14  [ZumaImpeachment, Khoisan, CR17, ANC54, LandEx...
# 15                                [Zuma, ANCFireZuma]
# 16                             [Zuma, cyrilramaphosa]
# 17                                             [Zuma]
# 18                                             [Zuma]
# 19                                             [zuma]
# 20               [Nkandla, zuma, Zupta, ZumaMustFall]
# 21    [Impeachment, NewYearsResolutions, Trump, Zuma]
# 22  [NewYearsResolutions, DoctorWho, regeneration,...
# 23  [bitcoin, Extraterrestrial, corruption, vaccin...
# 24  [ArrestTomCotton, ArrestBenjaminNetanyahu, cor...
# 25           [Corruption, Courts, politicalprisoners]
# 26  [climatechange, plasticpollution, extinction, ...
# 27              [dishonest, corruption, HappyNewYear]
# 28  [NetEase, NewYearsEve2018, China, Putin, Russi...
# 29  [Treason, Corruption, Collusion, Blackmail, Im...
# 30                         [corruption, constitution]
# 31                        [Justice, Corruption, Utah]
# 32  [QAnon, Black, Swan, White, Hat, Ambassador, W...
