# %%
import pandas as pd
from textblob import TextBlob

# %%
df1 = pd.read_csv('anc_clean_2014.csv')
df2 = pd.read_csv('da_clean_2014.csv')
df3 = pd.read_csv('eff_clean_2014.csv')
df4 = pd.read_csv('ifp_clean_2014.csv')
# Out:
#                                                    Text           Datetime  \
# 0     remember support fantastic work vote continue ...  17:12:31 05:49:18
# 1     zumaimpeachment opposition parties would want ...  17:12:30 18:46:24
# 2             vote anc dasmalema president south africa  17:12:30 15:41:47
# 3     must vote motion shall vote motion anc best un...  17:12:29 20:14:38
# 4     excitement zumaimpeachment process restarting ...  17:12:29 11:04:54
# ...                                                 ...                ...
# 1772            motlanthe sure vote anc 2019 eff da ifp  17:04:26 14:50:38
# 1773  please anc keep zuma dynasty going best electi...  17:04:24 09:25:23
# 1774      vdmerwe lol awesome liezl make proud vote ifp  17:04:10 19:07:09
# 1775  buthelezi says next motion confidence futile e...  17:04:03 14:34:55
# 1776  ifp didnt vote legislature motion confidencekwaza  17:02:28 15:24:40
#
#                         Location  \
# 0                   South Africa
# 1        Milnerton, South Africa
# 2                   South Africa
# 3          Gauteng, South Africa
# 4                   Johannesburg
# ...                          ...
# 1772                South Africa
# 1773                South Africa
# 1774                South Africa
# 1775  Johannesburg, South Africa
# 1776        Soweto, South Africa
#
#                                                Hashtags  polarity  \
# 0                                               ['ANC']  0.400000
# 1                            ['ZumaImpeachment', 'ANC']  0.000000
# 2                                               ['ANC']  0.000000
# 3                                    ['ANC', 'Zuma783']  0.300000
# 4                            ['ZumaImpeachment', 'ANC']  0.200000
# ...                                                 ...       ...
# 1772           ['Motlanthe', 'ANC', 'EFF', 'DA', 'IFP']  0.500000
# 1773  ['ANC', 'Zuma', 'EFF', 'DA', 'UDM', 'IFP', 'CO...  1.000000
# 1774                                            ['IFP']  0.866667
# 1775                                            ['IFP']  0.000000
# 1776                                            ['IFP']  0.000000
#
#       subjectivity
# 0         0.900000
# 1         0.000000
# 2         0.000000
# 3         0.425000
# 4         0.200000
# ...            ...
# 1772      0.888889
# 1773      0.300000
# 1774      0.900000
# 1775      0.000000
# 1776      0.000000
#
# [1777 rows x 6 columns]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
def get_polarity(text):
    return TextBlob(text).sentiment.polarity

def get_subjectivity(text):
    return TextBlob(text).sentiment.subjectivity

df['polarity'] = df['Text'].apply(get_polarity)
df['subjectivity'] = df['Text'].apply(get_subjectivity)
df.to_csv('vote_clean_2014.csv', index=False)
