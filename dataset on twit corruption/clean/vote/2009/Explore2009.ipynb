# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv("vote_clean_2009.csv")
df.dropna(inplace=True)
df
# Out:
#                                                  Text             Datetime  \
# 0   anc 6527 da 1637 cope744 ifp 502 id 097 vf 092...  2022-11-29 17:45:34
# 1                  anc6527da1637cope744saelectionsanc  2022-11-29 17:38:53
# 2                  rt lol anc election poster stencil  2022-11-29 08:51:32
# 3                     lol anc election poster stencil  2022-11-29 08:46:08
# 4   domestic worker says motherwell pe anc going d...  2022-11-29 14:56:07
# 5   rt domestic worker says motherwell pe anc goin...  2022-11-29 11:57:47
# 6   domestic worker says motherwell pe anc going d...  2022-11-29 11:34:55
# 7   retweet regards sapolitics shall vote anc cant...  2022-11-29 19:14:12
# 8   anc 6527 da 1637 cope744 ifp 502 id 097 vf 092...  2022-11-29 17:45:34
# 9   10000 south africans voted overseas 77 da thin...  2022-11-29 08:12:01
# 10  voted sandton sports club 12min queue super fr...  2022-11-29 18:55:37
# 11  suck politician shots cellphone attached tony ...  2022-11-29 15:06:11
# 12  rt another sms vanilla shriller da time afrika...  2022-11-29 13:16:51
# 13  another sms vanilla shriller da time afrikaans...  2022-11-29 13:11:44
# 14  still vote unless something drastic happens ne...  2022-11-29 09:10:33
# 15  mrs zille says back move npa hopes da saelections  2022-11-29 17:52:08
# 16  da public address benoni town hall try tweet h...  2022-11-29 17:03:16
# 17  dear party get number think unconstitutional a...  2022-11-29 04:59:28
# 18  rt hear malema lot say today matter every time...  2022-11-29 17:59:16
# 19  anc 6527 da 1637 cope744 ifp 502 id 097 vf 092...  2022-11-29 17:45:34
#
#                       Location  \
# 0                     Pretoria
# 1                     Pretoria
# 2      Cape Town, South Africa
# 3   Johannesburg, South Africa
# 4      Cape Town, South Africa
# 5                    cape town
# 6      Cape Town, South Africa
# 7      Cape Town, South Africa
# 8                     Pretoria
# 9      Cape Town, South Africa
# 10  Johannesburg, South Africa
# 11                   Cape Town
# 12                   Cape Town
# 13     Cape Town, South Africa
# 14  Johannesburg, South Africa
# 15     Cape Town, South Africa
# 16     Cape Town, South Africa
# 17                South Africa
# 18                   Cape Town
# 19                    Pretoria
#
#                                              Hashtags  polarity  subjectivity
# 0   ['ANC', 'DA', 'COPE', 'IFP', 'ID', 'VF', 'UDM'...  0.000000      0.000000
# 1                              ['ANC', 'saelections']  0.000000      0.000000
# 2                                             ['anc']  0.800000      0.700000
# 3                                             ['anc']  0.800000      0.700000
# 4                                             ['ANC']  0.000000      0.100000
# 5                              ['ANC', 'saelections']  0.000000      0.100000
# 6                              ['ANC', 'saelections']  0.000000      0.100000
# 7                               ['SApolitics', 'ANC']  1.000000      1.000000
# 8   ['ANC', 'DA', 'COPE', 'IFP', 'ID', 'VF', 'UDM'...  0.000000      0.000000
# 9                                              ['DA']  0.000000      0.000000
# 10                       ['IEC', 'saelections', 'DA']  0.354167      0.583333
# 11                              ['saelections', 'da']  0.000000      0.000000
# 12                              ['DA', 'saelections'] -0.166667      0.583333
# 13                              ['DA', 'saelections'] -0.166667      0.583333
# 14                                             ['DA']  0.000000      0.000000
# 15                              ['DA', 'saelections']  0.000000      0.000000
# 16                              ['DA', 'saelections']  0.000000      0.066667
# 17                                     ['DA', 'fail'] -0.500000      0.300000
# 18                                   ['Malema', 'DA']  0.000000      0.000000
# 19  ['ANC', 'DA', 'COPE', 'IFP', 'ID', 'VF', 'UDM'...  0.000000      0.000000

# %%
df.shape
# Out:
# (20, 6)

# %%
#plot the number of tweets per day
df['Datetime'] = pd.to_datetime(df['Datetime'])
df['Datetime'].value_counts().plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#plot polarity and subjectivity scatter
#increase the size of the plot
plt.rcParams['figure.figsize'] = [10, 4]
plt.rcParams['lines.markersize'] = 10
plt.scatter(df['polarity'], df['subjectivity'], color='red')
plt.show()
