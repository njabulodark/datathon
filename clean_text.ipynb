# %%
import pandas as pd
import re
from textblob import TextBlob

# %%
df = pd.read_csv('2017data235636.csv')
df
# Out:
#                  Datetime                                               Text  \
# 0       17:12:31 23:59:14  @DoctorWho_BBCA #NewYearsResolutions May #Doct...
# 1       17:12:31 23:53:18  2018 will be remembered has the year when EVER...
# 2       17:12:31 23:49:49  #ArrestTomCotton\n#ArrestBenjaminNetanyahu\n#c...
# 3       17:12:31 23:40:44  @thehill I say protect Americans from #Corrupt...
# 4       17:12:31 23:33:25  Good luck for 2018 to all the dedicated folk d...
# ...                   ...                                                ...
# 235631  17:07:01 12:40:14  "We don't want #ANC to be destroyed by the wea...
# 235632  17:07:01 12:35:35  @News24 Quite simple uncle Gwede, you are all ...
# 235633  17:07:01 12:25:19  @ajnarsee #ImizamoYethu another example of fai...
# 235634  17:07:01 12:21:05  @aCzwe @HermanMashaba @isizulu @MYANC Right no...
# 235635  17:07:01 12:20:07  #InfoTricolor "Clase trabajadora marchará este...
#
#                Username  Retweets                    Location  \
# 0         AlbertFiorino         1             Toronto, Canada
# 1          lifemechanik         0                         NaN
# 2              Jory_Nal         0                Upper Canada
# 3        KeltonPrisbrey         0           St. George, Utah
# 4           BillHarvey6         4            Hobart, Tasmania
# ...                 ...       ...                         ...
# 235631            MYANC         8                South Africa
# 235632         hills007         0     Cape Town, South Africa
# 235633       siphokid29         0  Botshabelo Republic of SA.
# 235634             ESNK         4       3rd Rock From The Sun
# 235635  Barrio_Tricolor         5                   Venezuela
#
#                                                  Hashtags
# 0       ['NewYearsResolutions', 'DoctorWho', 'regenera...
# 1       ['bitcoin', 'Extraterrestrial', 'corruption', ...
# 2       ['ArrestTomCotton', 'ArrestBenjaminNetanyahu',...
# 3          ['Corruption', 'Courts', 'politicalprisoners']
# 4       ['climatechange', 'plasticpollution', 'extinct...
# ...                                                   ...
# 235631                                  ['ANC', 'ANCNPC']
# 235632                               ['butternut', 'ANC']
# 235633  ['ImizamoYethu', 'ANC', 'ANCNCP', 'ANCPolicyCo...
# 235634                                            ['ANC']
# 235635  ['InfoTricolor', 'ANC', 'VenezuelaTricolor', '...
#
# [235636 rows x 6 columns]

# %%
def clean_tweet(tweet):
    tweet = re.sub(r'@[A-Za-z0-9]+', '', tweet) #Removing @mentions
    tweet = re.sub(r'#', '', tweet) #Removing the '#' symbol
    tweet = re.sub(r'RT[\s]+', '', tweet) #Removing RT
    tweet = re.sub(r'https?:\/\/\S+', '', tweet) #Removing the hyper link
    return tweet

df['Text'] = df['Text'].apply(clean_tweet)
df

# %%
df2 = df[['Text', 'Datetime', 'Location']]
df2.dropna(inplace=True)
df2.reset_index(drop=True, inplace=True)
df2
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8664\1825179145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)
#                                                  Text           Datetime  \
# 0   HappyNewYear2018 All the way from CapeTown RSA...  17:12:31 23:54:51
# 1   Thought Factory (new): Patronage Politics in R...  17:12:31 23:25:03
# 2   Thought Factory: The DA's Ideological Schizoph...  17:12:31 23:05:09
# 3    Thank you Sandra . RSA SouthAfrica 🇿🇦🇬🇧 SuidA...  17:12:31 22:58:49
# 4         Dankie Sandra . 🇿🇦🇬🇧RSA SouthAfrica Africa   17:12:31 22:57:24
# 5   Thought Factory (new): The ‘Thief-in-Chief’ RS...  17:12:31 22:55:07
# 6   New - Business Day: Changing the system for su...  17:12:31 22:10:04
# 7   From London UK: Wishing South Africa 🇿🇦 a very...  17:12:31 22:04:11
# 8   Thought Factory (new): Patronage Politics in R...  17:12:31 22:00:30
# 9   At 10.00pm GMT, RSA (South Africa) will enter ...  17:12:31 21:57:47
# 10  Should ConCourt side with opposition, will MPs...  17:12:31 23:42:12
# 11    _New_Age _S_Malema There is only seats for x...  17:12:31 23:08:11
# 12  Thought Factory (new): The ‘Thief-in-Chief’ RS...  17:12:31 22:55:07
# 13  If we overcame 2017 with Zuma 2018 will be eas...  17:12:31 22:51:41
# 14  Read Frank Chikane's book. I'm inspired, again...  17:12:31 22:41:49
# 15  For all my followers in SA. Happy New Years fr...  17:12:31 22:02:46
# 16  Concourt to deliver judgment on Zuma impeachme...  17:12:31 21:45:40
# 17  zuma speak - empty sound byte - telling us sam...  17:12:31 21:00:03
# 18  2018 let it be year we South Africa show we ar...  17:12:31 20:53:47
# 19  _BBCA NewYearsResolutions May DoctorWho’s advi...  17:12:31 23:59:14
# 20  ArrestTomCotton\nArrestBenjaminNetanyahu\ncorr...  17:12:31 23:49:49
# 21   I say protect Americans from Corruption in th...  17:12:31 23:40:44
# 22  Good luck for 2018 to all the dedicated folk d...  17:12:31 23:33:25
# 23    I'm pretty sure he knows. More dishonest cor...  17:12:31 23:33:13
# 24   Hero vs. heel. \nTreason Corruption Collusion...  17:12:31 23:23:55
# 25  _elbaghdadi  We all need to stand united or th...  17:12:31 23:15:36
# 26   Chief Justice needs to order review of Justic...  17:12:31 23:12:00
# 27  QAnon Black Swan White Hat the saga of Ambassa...  17:12:31 23:10:38
#
#                           Location
# 0          Cape Town, South Africa
# 1          Cape Town, South Africa
# 2          Cape Town, South Africa
# 3   On GAB, Parler. I Follow Back.
# 4   On GAB, Parler. I Follow Back.
# 5          Cape Town, South Africa
# 6          Cape Town, South Africa
# 7   On GAB, Parler. I Follow Back.
# 8          Cape Town, South Africa
# 9               Llanrhystud, Wales
# 10                  Lagos, Nigeria
# 11                          Joburg
# 12         Cape Town, South Africa
# 13           Jo'burg. Gauteng, RSA
# 14          Pretoria, South Africa
# 15                  United Kingdom
# 16                  Lagos, Nigeria
# 17       Johannesburg South Africa
# 18       Johannesburg South Africa
# 19                 Toronto, Canada
# 20                    Upper Canada
# 21               St. George, Utah
# 22                Hobart, Tasmania
# 23                   United States
# 24                     Seattle, WA
# 25               St. George, Utah
# 26               St. George, Utah
# 27                   Vancouver, BC

# %%
#get if location in not sa make none
locations = ["pietermaritzburg", "sa", "southafrica","capetown" "durban", "johannesburg", "capetown", "pretoria", "bloemfontein", "port elizabeth", "polokwane", "nelspruit", "kimberley", "upington", "george", "mossel bay", "klerksdorp", "potchefstroom", "randburg", "sandton", "benoni", "boksburg", "brakpan", "centurion", "germiston", "kempton park", "midrand", "tembisa", "vanderbijlpark", "vereeniging", "alberton", "bryanston", "carletonville", "durban north", "edenvale", "fourways", "kagiso", "kwa-thema", "lenasia", "midvaal", "mpumalanga", "nigel", "randfontein", "roodepoort", "soweto", "springs",]

res = ''

def check_location(location):
    for loc in locations:
        print(loc)
        if loc in location:
            return location
    return None

def is_sa(location):
    for i in location:
        print(i)


for index, value in enumerate(df2["Location"]):
    value = value.lower().replace(" ", "").split(",")
    print(value)
    for i in value:
        print(i)
        if i in locations:
            df2["Location"][index] = "south africa"
            break
        else:
            df2["Location"][index] = None
df2
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8664\4171686051.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Location"][index] = "south africa"
# C:\Users\User\AppData\Local\Temp\ipykernel_8664\4171686051.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Location"][index] = None
# ['capetown', 'southafrica']
# capetown
# ['capetown', 'southafrica']
# capetown
# ['capetown', 'southafrica']
# capetown
# ['ongab', 'parler.ifollowback.']
# ongab
# parler.ifollowback.
# ['ongab', 'parler.ifollowback.']
# ongab
# parler.ifollowback.
# ['capetown', 'southafrica']
# capetown
# ['capetown', 'southafrica']
# capetown
# ['ongab', 'parler.ifollowback.']
# ongab
# parler.ifollowback.
# ['capetown', 'southafrica']
# capetown
# ['llanrhystud', 'wales']
# llanrhystud
# wales
# ['lagos', 'nigeria']
# lagos
# nigeria
# ['joburg']
# joburg
# ['capetown', 'southafrica']
# capetown
# ["jo'burg.gauteng", 'rsa']
# jo'burg.gauteng
# rsa
# ['pretoria', 'southafrica']
# pretoria
# ['unitedkingdom']
# unitedkingdom
# ['lagos', 'nigeria']
# lagos
# nigeria
# ['johannesburgsouthafrica']
# johannesburgsouthafrica
# ['johannesburgsouthafrica']
# johannesburgsouthafrica
# ['toronto', 'canada']
# toronto
# canada
# ['uppercanada']
# uppercanada
# ['st.george', 'utah']
# st.george
# utah
# ['hobart', 'tasmania']
# hobart
# tasmania
# ['unitedstates']
# unitedstates
# ['seattle', 'wa']
# seattle
# wa
# ['st.george', 'utah']
# st.george
# utah
# ['st.george', 'utah']
# st.george
# utah
# ['vancouver', 'bc']
# vancouver
# bc
#                                                  Text           Datetime  \
# 0   HappyNewYear2018 All the way from CapeTown RSA...  17:12:31 23:54:51
# 1   Thought Factory (new): Patronage Politics in R...  17:12:31 23:25:03
# 2   Thought Factory: The DA's Ideological Schizoph...  17:12:31 23:05:09
# 3    Thank you Sandra . RSA SouthAfrica 🇿🇦🇬🇧 SuidA...  17:12:31 22:58:49
# 4         Dankie Sandra . 🇿🇦🇬🇧RSA SouthAfrica Africa   17:12:31 22:57:24
# 5   Thought Factory (new): The ‘Thief-in-Chief’ RS...  17:12:31 22:55:07
# 6   New - Business Day: Changing the system for su...  17:12:31 22:10:04
# 7   From London UK: Wishing South Africa 🇿🇦 a very...  17:12:31 22:04:11
# 8   Thought Factory (new): Patronage Politics in R...  17:12:31 22:00:30
# 9   At 10.00pm GMT, RSA (South Africa) will enter ...  17:12:31 21:57:47
# 10  Should ConCourt side with opposition, will MPs...  17:12:31 23:42:12
# 11    _New_Age _S_Malema There is only seats for x...  17:12:31 23:08:11
# 12  Thought Factory (new): The ‘Thief-in-Chief’ RS...  17:12:31 22:55:07
# 13  If we overcame 2017 with Zuma 2018 will be eas...  17:12:31 22:51:41
# 14  Read Frank Chikane's book. I'm inspired, again...  17:12:31 22:41:49
# 15  For all my followers in SA. Happy New Years fr...  17:12:31 22:02:46
# 16  Concourt to deliver judgment on Zuma impeachme...  17:12:31 21:45:40
# 17  zuma speak - empty sound byte - telling us sam...  17:12:31 21:00:03
# 18  2018 let it be year we South Africa show we ar...  17:12:31 20:53:47
# 19  _BBCA NewYearsResolutions May DoctorWho’s advi...  17:12:31 23:59:14
# 20  ArrestTomCotton\nArrestBenjaminNetanyahu\ncorr...  17:12:31 23:49:49
# 21   I say protect Americans from Corruption in th...  17:12:31 23:40:44
# 22  Good luck for 2018 to all the dedicated folk d...  17:12:31 23:33:25
# 23    I'm pretty sure he knows. More dishonest cor...  17:12:31 23:33:13
# 24   Hero vs. heel. \nTreason Corruption Collusion...  17:12:31 23:23:55
# 25  _elbaghdadi  We all need to stand united or th...  17:12:31 23:15:36
# 26   Chief Justice needs to order review of Justic...  17:12:31 23:12:00
# 27  QAnon Black Swan White Hat the saga of Ambassa...  17:12:31 23:10:38
#
#         Location
# 0   south africa
# 1   south africa
# 2   south africa
# 3           None
# 4           None
# 5   south africa
# 6   south africa
# 7           None
# 8   south africa
# 9           None
# 10          None
# 11          None
# 12  south africa
# 13          None
# 14  south africa
# 15          None
# 16          None
# 17          None
# 18          None
# 19          None
# 20          None
# 21          None
# 22          None
# 23          None
# 24          None
# 25          None
# 26          None
# 27          None

# %%
def polarity(text):
    return TextBlob(text).sentiment.polarity

def subjectivity(text):
    return TextBlob(text).sentiment.subjectivity

df2['Polarity'] = df2['Text'].apply(polarity)
df2['Subjectivity'] = df2['Text'].apply(subjectivity)
df2
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8664\2249375356.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Polarity'] = df2['Text'].apply(polarity)
# C:\Users\User\AppData\Local\Temp\ipykernel_8664\2249375356.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Subjectivity'] = df2['Text'].apply(subjectivity)
#                                                  Text           Datetime  \
# 0   HappyNewYear2018 All the way from CapeTown RSA...  17:12:31 23:54:51
# 1   Thought Factory (new): Patronage Politics in R...  17:12:31 23:25:03
# 2   Thought Factory: The DA's Ideological Schizoph...  17:12:31 23:05:09
# 3    Thank you Sandra . RSA SouthAfrica 🇿🇦🇬🇧 SuidA...  17:12:31 22:58:49
# 4         Dankie Sandra . 🇿🇦🇬🇧RSA SouthAfrica Africa   17:12:31 22:57:24
# 5   Thought Factory (new): The ‘Thief-in-Chief’ RS...  17:12:31 22:55:07
# 6   New - Business Day: Changing the system for su...  17:12:31 22:10:04
# 7   From London UK: Wishing South Africa 🇿🇦 a very...  17:12:31 22:04:11
# 8   Thought Factory (new): Patronage Politics in R...  17:12:31 22:00:30
# 9   At 10.00pm GMT, RSA (South Africa) will enter ...  17:12:31 21:57:47
# 10  Should ConCourt side with opposition, will MPs...  17:12:31 23:42:12
# 11    _New_Age _S_Malema There is only seats for x...  17:12:31 23:08:11
# 12  Thought Factory (new): The ‘Thief-in-Chief’ RS...  17:12:31 22:55:07
# 13  If we overcame 2017 with Zuma 2018 will be eas...  17:12:31 22:51:41
# 14  Read Frank Chikane's book. I'm inspired, again...  17:12:31 22:41:49
# 15  For all my followers in SA. Happy New Years fr...  17:12:31 22:02:46
# 16  Concourt to deliver judgment on Zuma impeachme...  17:12:31 21:45:40
# 17  zuma speak - empty sound byte - telling us sam...  17:12:31 21:00:03
# 18  2018 let it be year we South Africa show we ar...  17:12:31 20:53:47
# 19  _BBCA NewYearsResolutions May DoctorWho’s advi...  17:12:31 23:59:14
# 20  ArrestTomCotton\nArrestBenjaminNetanyahu\ncorr...  17:12:31 23:49:49
# 21   I say protect Americans from Corruption in th...  17:12:31 23:40:44
# 22  Good luck for 2018 to all the dedicated folk d...  17:12:31 23:33:25
# 23    I'm pretty sure he knows. More dishonest cor...  17:12:31 23:33:13
# 24   Hero vs. heel. \nTreason Corruption Collusion...  17:12:31 23:23:55
# 25  _elbaghdadi  We all need to stand united or th...  17:12:31 23:15:36
# 26   Chief Justice needs to order review of Justic...  17:12:31 23:12:00
# 27  QAnon Black Swan White Hat the saga of Ambassa...  17:12:31 23:10:38
#
#         Location  Polarity  Subjectivity
# 0   south africa  0.000000      0.000000
# 1   south africa  0.136364      0.454545
# 2   south africa  0.000000      0.000000
# 3           None  0.000000      0.000000
# 4           None  0.000000      0.000000
# 5   south africa  0.136364      0.454545
# 6   south africa  0.136364      0.454545
# 7           None  0.568182      0.727273
# 8   south africa  0.136364      0.454545
# 9           None  0.000000      0.000000
# 10          None  0.000000      0.000000
# 11          None  0.307273      0.600909
# 12  south africa  0.136364      0.454545
# 13          None  0.433333      0.833333
# 14  south africa  0.000000      0.066667
# 15          None  0.468182      0.727273
# 16          None  0.000000      0.000000
# 17          None  0.100000      0.341667
# 18          None  0.333333      1.000000
# 19          None  0.000000      0.500000
# 20          None  0.000000      0.000000
# 21          None  0.000000      0.000000
# 22          None  0.395833      0.379167
# 23          None  0.240000      0.627778
# 24          None  0.000000      0.000000
# 25          None  0.000000      0.000000
# 26          None  0.000000      1.000000
# 27          None -0.055556      0.144444

# %%
#remove all rows with none in location
df2.dropna(inplace=True)
df2

df2.to_csv('2017data_cleaned.csv', index=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8664\2031101024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)
#                                                  Text           Datetime  \
# 0   HappyNewYear2018 All the way from CapeTown RSA...  17:12:31 23:54:51
# 1   Thought Factory (new): Patronage Politics in R...  17:12:31 23:25:03
# 2   Thought Factory: The DA's Ideological Schizoph...  17:12:31 23:05:09
# 5   Thought Factory (new): The ‘Thief-in-Chief’ RS...  17:12:31 22:55:07
# 6   New - Business Day: Changing the system for su...  17:12:31 22:10:04
# 8   Thought Factory (new): Patronage Politics in R...  17:12:31 22:00:30
# 12  Thought Factory (new): The ‘Thief-in-Chief’ RS...  17:12:31 22:55:07
# 14  Read Frank Chikane's book. I'm inspired, again...  17:12:31 22:41:49
#
#         Location  Polarity  Subjectivity
# 0   south africa  0.000000      0.000000
# 1   south africa  0.136364      0.454545
# 2   south africa  0.000000      0.000000
# 5   south africa  0.136364      0.454545
# 6   south africa  0.136364      0.454545
# 8   south africa  0.136364      0.454545
# 12  south africa  0.136364      0.454545
# 14  south africa  0.000000      0.066667
